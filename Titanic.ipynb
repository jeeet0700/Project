# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  adult_male  \
# 0         3    male  22.0      1      0   7.2500        S   Third        True
# 1         1  female  38.0      1      0  71.2833        C   First       False
# 2         3  female  26.0      0      0   7.9250        S   Third       False
# 3         1  female  35.0      1      0  53.1000        S   First       False
# 4         3    male  35.0      0      0   8.0500        S   Third        True
# ..      ...     ...   ...    ...    ...      ...      ...     ...         ...
# 886       2    male  27.0      0      0  13.0000        S  Second        True
# 887       1  female  19.0      0      0  30.0000        S   First       False
# 888       3  female   NaN      1      2  23.4500        S   Third       False
# 889       1    male  26.0      0      0  30.0000        C   First        True
# 890       3    male  32.0      0      0   7.7500        Q   Third        True
#
#      embark_town alive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pclass       891 non-null    int64
#  1   sex          891 non-null    object
#  2   age          714 non-null    float64
#  3   sibsp        891 non-null    int64
#  4   parch        891 non-null    int64
#  5   fare         891 non-null    float64
#  6   embarked     889 non-null    object
#  7   class        891 non-null    object
#  8   adult_male   891 non-null    bool
#  9   embark_town  889 non-null    object
#  10  alive        891 non-null    object
# dtypes: bool(1), float64(2), int64(3), object(5)
# memory usage: 70.6+ KB

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  adult_male  \
# 0         3    male  22.0      1      0   7.2500        S   Third        True
# 1         1  female  38.0      1      0  71.2833        C   First       False
# 2         3  female  26.0      0      0   7.9250        S   Third       False
# 3         1  female  35.0      1      0  53.1000        S   First       False
# 4         3    male  35.0      0      0   8.0500        S   Third        True
# ..      ...     ...   ...    ...    ...      ...      ...     ...         ...
# 886       2    male  27.0      0      0  13.0000        S  Second        True
# 887       1  female  19.0      0      0  30.0000        S   First       False
# 888       3  female   NaN      1      2  23.4500        S   Third       False
# 889       1    male  26.0      0      0  30.0000        C   First        True
# 890       3    male  32.0      0      0   7.7500        Q   Third        True
#
#      embark_town alive
# ...

# %% [markdown]
# # Diff. type of class

# %%
df['pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['pclass'].nunique()
# Out:
# 3

# %% [markdown]
# # Passenger class wise

# %%
df['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df.groupby(['pclass'])['sex'].count()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: sex, dtype: int64

# %% [markdown]
# # class wise sex ratio

# %%
df.groupby(['pclass'])['sex'].value_counts()
# Out:
# pclass  sex
# 1       male      122
#         female     94
# 2       male      108
#         female     76
# 3       male      347
#         female    144
# Name: sex, dtype: int64

# %% [markdown]
# # class fare comparision

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  adult_male  \
# 0         3    male  22.0      1      0   7.2500        S   Third        True
# 1         1  female  38.0      1      0  71.2833        C   First       False
# 2         3  female  26.0      0      0   7.9250        S   Third       False
# 3         1  female  35.0      1      0  53.1000        S   First       False
# 4         3    male  35.0      0      0   8.0500        S   Third        True
# ..      ...     ...   ...    ...    ...      ...      ...     ...         ...
# 886       2    male  27.0      0      0  13.0000        S  Second        True
# 887       1  female  19.0      0      0  30.0000        S   First       False
# 888       3  female   NaN      1      2  23.4500        S   Third       False
# 889       1    male  26.0      0      0  30.0000        C   First        True
# 890       3    male  32.0      0      0   7.7500        Q   Third        True
#
#      embark_town alive
# ...

# %%
df.groupby(['pclass'])['fare'].sum()
# Out:
# pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: fare, dtype: float64

# %%
df.groupby(['pclass'])['fare'].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
df.groupby(['pclass'])['fare'].min()
# Out:
# pclass
# 1    0.0
# 2    0.0
# 3    0.0
# Name: fare, dtype: float64

# %%
df.groupby(['pclass'])['fare'].max()
# Out:
# pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: fare, dtype: float64

# %%
df.groupby(['pclass'])[['fare']].agg(fare_min=('fare','min'),
                                  fare_max=('fare','max'))
# Out:
#         fare_min  fare_max
# pclass
# 1            0.0  512.3292
# 2            0.0   73.5000
# 3            0.0   69.5500

# %%
df.groupby(['pclass'])[['fare']].agg(fare_min=('fare','min'),
                                  fare_max=('fare','max')).reset_index()
# Out:
#    pclass  fare_min  fare_max
# 0       1       0.0  512.3292
# 1       2       0.0   73.5000
# 2       3       0.0   69.5500

# %%
df.groupby(['pclass'])[['fare']].agg(fare_min=('fare','min'),
                                  fare_max=('fare','max'),
                                    fare_mean=('fare','mean')).reset_index()
# Out:
#    pclass  fare_min  fare_max  fare_mean
# 0       1       0.0  512.3292  84.154687
# 1       2       0.0   73.5000  20.662183
# 2       3       0.0   69.5500  13.675550

# %%
df.groupby(['pclass'])[['fare','sex']].agg(fare_min=('fare','min'),
                                  fare_max=('fare','max'),
                                    fare_mean=('fare','mean'),
                                          sex_count=('sex','count')).reset_index()
# Out:
#    pclass  fare_min  fare_max  fare_mean  sex_count
# 0       1       0.0  512.3292  84.154687        216
# 1       2       0.0   73.5000  20.662183        184
# 2       3       0.0   69.5500  13.675550        491

# %%
df
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  adult_male  \
# 0         3    male  22.0      1      0   7.2500        S   Third        True
# 1         1  female  38.0      1      0  71.2833        C   First       False
# 2         3  female  26.0      0      0   7.9250        S   Third       False
# 3         1  female  35.0      1      0  53.1000        S   First       False
# 4         3    male  35.0      0      0   8.0500        S   Third        True
# ..      ...     ...   ...    ...    ...      ...      ...     ...         ...
# 886       2    male  27.0      0      0  13.0000        S  Second        True
# 887       1  female  19.0      0      0  30.0000        S   First       False
# 888       3  female   NaN      1      2  23.4500        S   Third       False
# 889       1    male  26.0      0      0  30.0000        C   First        True
# 890       3    male  32.0      0      0   7.7500        Q   Third        True
#
#      embark_town alive
# ...

# %%
df.groupby(['pclass'])['alive'].value_counts()
# Out:
# pclass  alive
# 1       yes      136
#         no        80
# 2       no        97
#         yes       87
# 3       no       372
#         yes      119
# Name: alive, dtype: int64

# %%
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  adult_male  \
# 0         3    male  22.0      1      0   7.2500        S   Third        True
# 1         1  female  38.0      1      0  71.2833        C   First       False
# 2         3  female  26.0      0      0   7.9250        S   Third       False
# 3         1  female  35.0      1      0  53.1000        S   First       False
# 4         3    male  35.0      0      0   8.0500        S   Third        True
# ..      ...     ...   ...    ...    ...      ...      ...     ...         ...
# 886       2    male  27.0      0      0  13.0000        S  Second        True
# 887       1  female  19.0      0      0  30.0000        S   First       False
# 888       3  female   NaN      1      2  23.4500        S   Third       False
# 889       1    male  26.0      0      0  30.0000        C   First        True
# 890       3    male  32.0      0      0   7.7500        Q   Third        True
#
#      embark_town alive
# ...
